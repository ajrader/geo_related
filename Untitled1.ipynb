# %%
import os
import sys
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
# %pwd
# Out:
# 'C:\\Users\\ARADER\\GitHub\\geo_related'

# %%
os.chdir('../datascience')

# %%
CODE_DIR = 'C:/Users/ARADER/GitHub/'
# %load_ext autoreload
# %autoreload 2
sys.path.append(CODE_DIR+"datascience/") 
from datascience.utils import geoUtils
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
geoUtils.US_STATES_JSON
# Out:
# 'us-states.json'

# %%
import folium

# %%
us_states_data = json.load(open(os.path.join('datascience/utils/',geoUtils.US_STATES_JSON)))

# %%
lower48_data = {}
lower48_data['type']=us_states_data['type']
lower48_data['features']=[]
for f in us_states_data['features']:
    if f['properties']['name'] in ['Alaska','Hawaii']: 
        print(f) 
    else:
        lower48_data['features'].append(f)
# Out:
# {'type': 'Feature', 'id': '02', 'properties': {'name': 'Alaska', 'density': 1.264}, 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[-131.602021, 55.117982], [-131.569159, 55.28229], [-131.355558, 55.183705], [-131.38842, 55.01392], [-131.645836, 55.035827], [-131.602021, 55.117982]]], [[[-131.832052, 55.42469], [-131.645836, 55.304197], [-131.749898, 55.128935], [-131.832052, 55.189182], [-131.832052, 55.42469]]], [[[-132.976733, 56.437924], [-132.735747, 56.459832], [-132.631685, 56.421493], [-132.664547, 56.273616], [-132.878148, 56.240754], [-133.069841, 56.333862], [-132.976733, 56.437924]]], [[[-133.595627, 56.350293], [-133.162949, 56.317431], [-133.05341, 56.125739], [-132.620732, 55.912138], [-132.472854, 55.780691], [-132.4619, 55.671152], [-132.357838, 55.649245], [-132.341408, 55.506844], [-132.166146, 55.364444], [-132.144238, 55.238474], [-132.029222, 55.276813], [-131.97993, 55.178228], [-131.958022, 54.789365], [-132.029222, 54.701734], [-132.308546, 54.718165]
# ...

# %%
len(lower48_data['features'])
# Out:
# 50

# %%
m = folium.Map([43,-100], zoom_start=5)
us_data = geoUtils.load_us_states_file()
folium.GeoJson(us_data).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
us_states_file = os.path.join('datascience/utils/',geoUtils.US_STATES_JSON)

# %%
# %matplotlib inline

# %%
import geopandas

gdf = geopandas.read_file(us_states_file)

m = folium.Map([43, -100], zoom_start=4)

folium.GeoJson(
    gdf,
).add_to(m)

#m.save(os.path.join('results', 'GeoJSON_and_choropleth_3.html'))

m
# Out:
# WARNING:Fiona:GDAL data files not located, GDAL_DATA not set
# WARNING:Fiona:PROJ data files not located, PROJ_LIB not set
# WARNING:Fiona:GDAL data files not located, GDAL_DATA not set
# WARNING:Fiona:PROJ data files not located, PROJ_LIB not set
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map([43, -100], zoom_start=4)
folium.GeoJson(
    us_states_data,
    style_function=lambda feature: {
        'fillColor': 'green' if 'e' in feature['properties']['name'].lower() else '#ffff00',
        'color': 'black',
        'weight': 2,
        'dashArray': '5, 5'
    }
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map([43, -100], zoom_start=4)

m.choropleth(
    geo_data=gdf, #geopandas.read_file(us_states_file),
    fill_color='red',
    fill_opacity=0.3,
    line_weight=2,
)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
gdf = geopandas.read_file(us_states_file)
gdf = gdf[~gdf.name.isin(['Alaska','Hawaii','Puerto Rico'])]
len(gdf)
# Out:
# WARNING:Fiona:GDAL data files not located, GDAL_DATA not set
# WARNING:Fiona:PROJ data files not located, PROJ_LIB not set
# 49

# %%
m = geoUtils.create_folium_choro()
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
