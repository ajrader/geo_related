# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fname = '../datasets/testData_shovel1.csv'
d = pd.read_csv(fname)
d.drop('Unnamed: 4',1,inplace=True)

# %%
d.columns = ['Lat','Long','VIN','ViolDate']
d.columns
# Out:
# Index([u'Lat', u'Long', u'VIN', u'ViolDate'], dtype='object')

# %%
byVIN = d.groupby('VIN')

# %%
for g in byVIN.groups:
    print g
# Out:
#   1GYEK63N93R159216
#  5FNRL38245B089683
#  2FMDK4KC3ABA51708
#  5XYZG3AB0CG093556
#  JS2YB417685104920
#  1G4GC5EG1AF238135
#  P6FH213196
#  2D4GP44L07R132281
#  1FTPX12564NB51278
#  5GZEV23728J128014
#  2FMZA534XXBB66000
#  1G1AD5F51A7237851
#  1G6KD57Y06U200242
#  2GNALDEK7C6168041
#  1B7GL22N3YS720855
#  1B7HG48N42S691532
#  1YVHP80C185M32824
#  2T1BR32E05C386053
#  1HD1GGL11SY312733
#  1NXBR32E95Z392285
#  4T1BE30K04U337436
#  1HKJ171977
#  1P4GP44G8XB588409
#  1G6KE54Y74U208224
#  2B4GP44322R778523
#  JTDKB20U887762609
#  1FTCR10A6VUB14294
#  3N1AB61E07L623565
#  1P3ES46C0YD584736
#  1HGCG1649YA047639
#  4JGAB54EXYA176136
#  JKAEXMF1XWA056551
#  JT4RN81P0K0011439
#  1FDEE14H0SHA04319
#  1MEFM55S51G638368
#  4T1BF22K4VU035945
#  2A4RR8DG4BR688008
#  2HNYD18204H503042
#  YV4SZ592X71257782
#  1G8ZV57B59F158528
#  KMHDN46D45U076644
#  KM8SC13D73U352019
#  WAUBA24BXWN185566
#  5XYZH4AG0CG129597
#  1FTCR10A1TUD70307
#  2G1FP32K2V2157274
#  1FTCR10A7PUC27819
#  JNKBV61E37M723236
# ...

# %%
g
# Out:
# ' 1GNSKJE70CR180778'

# %%
byVIN.get_group(g)
# Out:
#             Lat       Long                 VIN  \
# 20    42.307922 -88.391739   1GNSKJE70CR180778
# 39    42.307922 -88.391739   1GNSKJE70CR180778
# 60    42.307922 -88.391739   1GNSKJE70CR180778
# 82    42.307922 -88.391739   1GNSKJE70CR180778
# 102   42.307922 -88.391739   1GNSKJE70CR180778
# 124   42.307922 -88.391739   1GNSKJE70CR180778
# 145   42.307922 -88.391739   1GNSKJE70CR180778
# 167   42.307922 -88.391739   1GNSKJE70CR180778
# 188   42.307922 -88.391739   1GNSKJE70CR180778
# 208   42.307922 -88.391739   1GNSKJE70CR180778
# 231   42.307922 -88.391739   1GNSKJE70CR180778
# 251   42.307922 -88.391739   1GNSKJE70CR180778
# 273   42.307922 -88.391739   1GNSKJE70CR180778
# 292   42.307922 -88.391739   1GNSKJE70CR180778
# 314   42.307922 -88.391739   1GNSKJE70CR180778
# 336   42.307922 -88.391739   1GNSKJE70CR180778
# 358   42.307922 -88.391739   1GNSKJE70CR180778
# 377   42.307922 -88.391739   1GNSKJE70CR180778
# 399   42.307922 -88.391739   1GNSKJE70CR180778
# ...
